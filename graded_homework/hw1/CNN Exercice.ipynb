# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    train_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader()
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 43.1MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Let's first talk about the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# For that, we will have some quick questions to see if you understand what happens during training/inference:
#
# ### 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** `torch.Size([6, 3, 5, 5])`
#
# ANSWER: D - 6 output channels, 3 input channels (RGB image), and 5x5 kernel (since 32x32 -> 28x28 and stride is 1 and no padding mentioned)
#
# ---
#
# ### 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** `2x2, yes it does`
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`
#
# ANSWER: A - 28x28 becomes 14x14 and stride = 2, so window must be 2x2. Subsampling method doesn't change this
#
# ---
#
# ### 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?
#
# ANSWER: Yes, that is how they are learned from data
#
# ---
#
# ### 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.
#
# ANSWER: We want the network to classify something. The conv layers create feature maps (edges, textures, etc) that the FC layer maps to a fixed number range of outputs. It turns them into a single classification decision.
#
# ---
#
# If you had any struggle to answer one of theses questions, feel free to ask a TA about intuition or hints about the solution.

# %% [markdown]
# # Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()

        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################
        pass

        self.features = nn.Sequential(
            # Input: 3x32x32
            # Output: 16x28x28
            nn.Conv2d(in_channels=n_input_channels, out_channels=16, kernel_size=5),
            nn.ReLU(),

            # Input: 16x28x28
            # Output: 16x14x14
            nn.MaxPool2d(2, 2),

            # Input: 16x14x14
            # Output: 32x10x10
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5),
            nn.ReLU(),

            # Input: 32x10x10
            # Output: 32x5x5
            nn.MaxPool2d(2, 2),

            nn.Flatten(1),
            nn.Linear(in_features=32*5*5, out_features=100),
            nn.Linear(in_features=100, out_features=n_output),
        )

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################


    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################

        return self.features(x)

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################


    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits, dim=1)

# %%
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

net = ConvNet().to(device)
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

epochs = 10
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):
        images = images.to(device)
        labels = labels.to(device)

        steps += 1

        # print(images.shape)

        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        optimizer.zero_grad()
        output = net(images) # Get the logits, since CrossEntropyLoss already calculates Softmax internally
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, labels)

        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            # Use net eval and torch no grad so pytotch doesn't track gradients when in evals
            net.eval()
            with torch.no_grad():
                accuracy = 0
                for ii, (images, labels) in enumerate(valloader):
                    images = images.to(device)
                    labels = labels.to(device)

                    ################################################################################
                    # TODO:                                                                        #
                    # Calculate the accuracy                                                       #
                    ################################################################################

                    probs = net.predict(images)
                    preds = torch.argmax(probs, dim=1)

                    accuracy += (preds == labels).float().mean().item()
                    ################################################################################
                    #                              END OF YOUR CODE                                #
                    ################################################################################

                print("Epoch: {}/{}..".format(e+1, epochs),
                    "Loss: {:.4f}..".format(running_loss/print_every),
                    "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                    "{:.4f} s/batch".format((stop - start)/print_every)
                    )
                running_loss = 0
                start = time.time()
            net.train()
# Out:
# Epoch: 1/10.. Loss: 2.1387.. Test accuracy: 0.2814.. 0.0758 s/batch
# Epoch: 1/10.. Loss: 1.9623.. Test accuracy: 0.3258.. 0.0157 s/batch
# Epoch: 1/10.. Loss: 1.8228.. Test accuracy: 0.3598.. 0.0138 s/batch
# Epoch: 1/10.. Loss: 1.6975.. Test accuracy: 0.4068.. 0.0141 s/batch
# Epoch: 1/10.. Loss: 1.6304.. Test accuracy: 0.3838.. 0.0147 s/batch
# Epoch: 1/10.. Loss: 1.6283.. Test accuracy: 0.4170.. 0.0136 s/batch
# Epoch: 1/10.. Loss: 1.6144.. Test accuracy: 0.4529.. 0.0152 s/batch
# Epoch: 1/10.. Loss: 1.5557.. Test accuracy: 0.4533.. 0.0163 s/batch
# Epoch: 1/10.. Loss: 1.5085.. Test accuracy: 0.4557.. 0.0139 s/batch
# Epoch: 1/10.. Loss: 1.4998.. Test accuracy: 0.4289.. 0.0139 s/batch
# Epoch: 1/10.. Loss: 1.4689.. Test accuracy: 0.4461.. 0.0140 s/batch
# Epoch: 1/10.. Loss: 1.4432.. Test accuracy: 0.4582.. 0.0144 s/batch
# Epoch: 1/10.. Loss: 1.4601.. Test accuracy: 0.4594.. 0.0188 s/batch
# Epoch: 1/10.. Loss: 1.4613.. Test accuracy: 0.4670.. 0.0222 s/batch
# Epoch: 1/10.. Loss: 1.4122.. Test accuracy: 0.4766.. 0.0194 s/batch
# Epoch: 1/10.. Loss: 1.3871.. Test accuracy: 0.4951.. 0.0238 s/batch
# Epoch: 1/10.. Loss: 1.4123.. Test accuracy: 0.4801.. 0.0219 s/batch
# Epoch: 1/10.. Loss: 1.3443.. Test accuracy: 0.5270.. 0.0130 s/batch
# Epoch: 1/10.. Loss: 1.3872.. Test accuracy: 0.5107.. 0.0143 s/batch
# Epoch: 1/10.. Loss: 1.3696.. Test accuracy: 0.5316.. 0.0135 s/batch
# Epoch: 1/10.. Loss: 1.3344.. Test accuracy: 0.5189.. 0.0139 s/batch
# Epoch: 1/10.. Loss: 1.3712.. Test accuracy: 0.5355.. 0.0137 s/batch
# Epoch: 1/10.. Loss: 1.2811.. Test accuracy: 0.4949.. 0.0135 s/batch
# Epoch: 1/10.. Loss: 1.2894.. Test accuracy: 0.5184.. 0.0134 s/batch
# Epoch: 1/10.. Loss: 1.2879.. Test accuracy: 0.5309.. 0.0148 s/batch
# Epoch: 1/10.. Loss: 1.3206.. Test accuracy: 0.5498.. 0.0132 s/batch
# Epoch: 1/10.. Loss: 1.2555.. Test accuracy: 0.5234.. 0.0135 s/batch
# Epoch: 1/10.. Loss: 1.3210.. Test accuracy: 0.5570.. 0.0142 s/batch
# Epoch: 1/10.. Loss: 1.3096.. Test accuracy: 0.5291.. 0.0141 s/batch
# Epoch: 1/10.. Loss: 1.2350.. Test accuracy: 0.5465.. 0.0148 s/batch
# Epoch: 1/10.. Loss: 1.2692.. Test accuracy: 0.5098.. 0.0134 s/batch
# Epoch: 1/10.. Loss: 1.2947.. Test accuracy: 0.5486.. 0.0137 s/batch
# Epoch: 1/10.. Loss: 1.2144.. Test accuracy: 0.5256.. 0.0227 s/batch
# Epoch: 1/10.. Loss: 1.2479.. Test accuracy: 0.5582.. 0.0209 s/batch
# Epoch: 1/10.. Loss: 1.2415.. Test accuracy: 0.5672.. 0.0238 s/batch
# Epoch: 1/10.. Loss: 1.1981.. Test accuracy: 0.5469.. 0.0190 s/batch
# Epoch: 1/10.. Loss: 1.2703.. Test accuracy: 0.5678.. 0.0197 s/batch
# Epoch: 1/10.. Loss: 1.2032.. Test accuracy: 0.5689.. 0.0193 s/batch
# Epoch: 2/10.. Loss: 1.1831.. Test accuracy: 0.5555.. 0.0184 s/batch
# Epoch: 2/10.. Loss: 1.2180.. Test accuracy: 0.5658.. 0.0147 s/batch
# Epoch: 2/10.. Loss: 1.1955.. Test accuracy: 0.5361.. 0.0129 s/batch
# Epoch: 2/10.. Loss: 1.1984.. Test accuracy: 0.5729.. 0.0140 s/batch
# Epoch: 2/10.. Loss: 1.1617.. Test accuracy: 0.5912.. 0.0150 s/batch
# Epoch: 2/10.. Loss: 1.1543.. Test accuracy: 0.5686.. 0.0137 s/batch
# Epoch: 2/10.. Loss: 1.1402.. Test accuracy: 0.5871.. 0.0135 s/batch
# Epoch: 2/10.. Loss: 1.0595.. Test accuracy: 0.5826.. 0.0134 s/batch
# Epoch: 2/10.. Loss: 1.1639.. Test accuracy: 0.5639.. 0.0139 s/batch
# Epoch: 2/10.. Loss: 1.2008.. Test accuracy: 0.5803.. 0.0149 s/batch
# Epoch: 2/10.. Loss: 1.1184.. Test accuracy: 0.6043.. 0.0142 s/batch
# Epoch: 2/10.. Loss: 1.1315.. Test accuracy: 0.6008.. 0.0138 s/batch
# Epoch: 2/10.. Loss: 1.1417.. Test accuracy: 0.6055.. 0.0142 s/batch
# Epoch: 2/10.. Loss: 1.1953.. Test accuracy: 0.5984.. 0.0138 s/batch
# Epoch: 2/10.. Loss: 1.1287.. Test accuracy: 0.5984.. 0.0226 s/batch
# Epoch: 2/10.. Loss: 1.0765.. Test accuracy: 0.6111.. 0.0242 s/batch
# Epoch: 2/10.. Loss: 1.0968.. Test accuracy: 0.6117.. 0.0223 s/batch
# Epoch: 2/10.. Loss: 1.0892.. Test accuracy: 0.6008.. 0.0218 s/batch
# Epoch: 2/10.. Loss: 1.0986.. Test accuracy: 0.5840.. 0.0172 s/batch
# Epoch: 2/10.. Loss: 1.1902.. Test accuracy: 0.6010.. 0.0156 s/batch
# Epoch: 2/10.. Loss: 1.1059.. Test accuracy: 0.6133.. 0.0147 s/batch
# Epoch: 2/10.. Loss: 1.0660.. Test accuracy: 0.6107.. 0.0132 s/batch
# Epoch: 2/10.. Loss: 1.1202.. Test accuracy: 0.6100.. 0.0135 s/batch
# Epoch: 2/10.. Loss: 1.1013.. Test accuracy: 0.5863.. 0.0150 s/batch
# Epoch: 2/10.. Loss: 1.0927.. Test accuracy: 0.5809.. 0.0157 s/batch
# Epoch: 2/10.. Loss: 1.1377.. Test accuracy: 0.5883.. 0.0143 s/batch
# Epoch: 2/10.. Loss: 1.1153.. Test accuracy: 0.6225.. 0.0144 s/batch
# Epoch: 2/10.. Loss: 1.1243.. Test accuracy: 0.6000.. 0.0154 s/batch
# Epoch: 2/10.. Loss: 1.1097.. Test accuracy: 0.6150.. 0.0143 s/batch
# Epoch: 2/10.. Loss: 1.0796.. Test accuracy: 0.6168.. 0.0146 s/batch
# Epoch: 2/10.. Loss: 1.1163.. Test accuracy: 0.6219.. 0.0132 s/batch
# Epoch: 2/10.. Loss: 1.0806.. Test accuracy: 0.6215.. 0.0134 s/batch
# Epoch: 2/10.. Loss: 1.0655.. Test accuracy: 0.6309.. 0.0146 s/batch
# Epoch: 2/10.. Loss: 1.0928.. Test accuracy: 0.6049.. 0.0203 s/batch
# Epoch: 2/10.. Loss: 1.0704.. Test accuracy: 0.6117.. 0.0226 s/batch
# Epoch: 2/10.. Loss: 1.0805.. Test accuracy: 0.6041.. 0.0213 s/batch
# Epoch: 2/10.. Loss: 1.0327.. Test accuracy: 0.6105.. 0.0236 s/batch
# Epoch: 2/10.. Loss: 1.0596.. Test accuracy: 0.6303.. 0.0209 s/batch
# Epoch: 3/10.. Loss: 1.0151.. Test accuracy: 0.6029.. 0.0142 s/batch
# Epoch: 3/10.. Loss: 1.0190.. Test accuracy: 0.6266.. 0.0220 s/batch
# Epoch: 3/10.. Loss: 1.0095.. Test accuracy: 0.6342.. 0.0146 s/batch
# Epoch: 3/10.. Loss: 1.0186.. Test accuracy: 0.6246.. 0.0130 s/batch
# Epoch: 3/10.. Loss: 1.0876.. Test accuracy: 0.6133.. 0.0162 s/batch
# Epoch: 3/10.. Loss: 1.0531.. Test accuracy: 0.6104.. 0.0149 s/batch
# Epoch: 3/10.. Loss: 1.0491.. Test accuracy: 0.6197.. 0.0144 s/batch
# Epoch: 3/10.. Loss: 1.0572.. Test accuracy: 0.6117.. 0.0154 s/batch
# Epoch: 3/10.. Loss: 1.0022.. Test accuracy: 0.6152.. 0.0148 s/batch
# Epoch: 3/10.. Loss: 1.0614.. Test accuracy: 0.6027.. 0.0145 s/batch
# Epoch: 3/10.. Loss: 1.0531.. Test accuracy: 0.5996.. 0.0144 s/batch
# Epoch: 3/10.. Loss: 1.0319.. Test accuracy: 0.6400.. 0.0130 s/batch
# Epoch: 3/10.. Loss: 1.0133.. Test accuracy: 0.5980.. 0.0148 s/batch
# Epoch: 3/10.. Loss: 1.0339.. Test accuracy: 0.6111.. 0.0161 s/batch
# Epoch: 3/10.. Loss: 0.9892.. Test accuracy: 0.5977.. 0.0191 s/batch
# Epoch: 3/10.. Loss: 1.0011.. Test accuracy: 0.6203.. 0.0236 s/batch
# Epoch: 3/10.. Loss: 1.0294.. Test accuracy: 0.6236.. 0.0234 s/batch
# Epoch: 3/10.. Loss: 1.0144.. Test accuracy: 0.5992.. 0.0226 s/batch
# Epoch: 3/10.. Loss: 1.0673.. Test accuracy: 0.6076.. 0.0243 s/batch
# Epoch: 3/10.. Loss: 1.0620.. Test accuracy: 0.6180.. 0.0137 s/batch
# Epoch: 3/10.. Loss: 1.0713.. Test accuracy: 0.6047.. 0.0120 s/batch
# Epoch: 3/10.. Loss: 1.0663.. Test accuracy: 0.6115.. 0.0153 s/batch
# Epoch: 3/10.. Loss: 1.0764.. Test accuracy: 0.6131.. 0.0146 s/batch
# Epoch: 3/10.. Loss: 1.0453.. Test accuracy: 0.6174.. 0.0138 s/batch
# Epoch: 3/10.. Loss: 1.0405.. Test accuracy: 0.6221.. 0.0140 s/batch
# Epoch: 3/10.. Loss: 1.0199.. Test accuracy: 0.6184.. 0.0157 s/batch
# Epoch: 3/10.. Loss: 1.0109.. Test accuracy: 0.5988.. 0.0145 s/batch
# Epoch: 3/10.. Loss: 1.0433.. Test accuracy: 0.6088.. 0.0137 s/batch
# Epoch: 3/10.. Loss: 1.0612.. Test accuracy: 0.5910.. 0.0157 s/batch
# Epoch: 3/10.. Loss: 1.0048.. Test accuracy: 0.6326.. 0.0141 s/batch
# Epoch: 3/10.. Loss: 1.0358.. Test accuracy: 0.6305.. 0.0145 s/batch
# Epoch: 3/10.. Loss: 1.0058.. Test accuracy: 0.6396.. 0.0150 s/batch
# Epoch: 3/10.. Loss: 0.9915.. Test accuracy: 0.6172.. 0.0146 s/batch
# Epoch: 3/10.. Loss: 0.9990.. Test accuracy: 0.6391.. 0.0145 s/batch
# Epoch: 3/10.. Loss: 0.9363.. Test accuracy: 0.6408.. 0.0184 s/batch
# Epoch: 3/10.. Loss: 1.0009.. Test accuracy: 0.6396.. 0.0234 s/batch
# Epoch: 3/10.. Loss: 1.0257.. Test accuracy: 0.6406.. 0.0236 s/batch
# Epoch: 3/10.. Loss: 1.0101.. Test accuracy: 0.6469.. 0.0225 s/batch
# Epoch: 4/10.. Loss: 0.9879.. Test accuracy: 0.6453.. 0.0093 s/batch
# Epoch: 4/10.. Loss: 0.9140.. Test accuracy: 0.6316.. 0.0139 s/batch
# Epoch: 4/10.. Loss: 0.9678.. Test accuracy: 0.6412.. 0.0148 s/batch
# Epoch: 4/10.. Loss: 0.9376.. Test accuracy: 0.6393.. 0.0150 s/batch
# Epoch: 4/10.. Loss: 0.9908.. Test accuracy: 0.6221.. 0.0145 s/batch
# Epoch: 4/10.. Loss: 0.9653.. Test accuracy: 0.6334.. 0.0141 s/batch
# Epoch: 4/10.. Loss: 0.9654.. Test accuracy: 0.6057.. 0.0152 s/batch
# Epoch: 4/10.. Loss: 0.9571.. Test accuracy: 0.6482.. 0.0139 s/batch
# Epoch: 4/10.. Loss: 0.9762.. Test accuracy: 0.6273.. 0.0146 s/batch
# Epoch: 4/10.. Loss: 1.0030.. Test accuracy: 0.6166.. 0.0157 s/batch
# Epoch: 4/10.. Loss: 0.9369.. Test accuracy: 0.6264.. 0.0145 s/batch
# Epoch: 4/10.. Loss: 0.9269.. Test accuracy: 0.6150.. 0.0147 s/batch
# Epoch: 4/10.. Loss: 0.9389.. Test accuracy: 0.6314.. 0.0132 s/batch
# Epoch: 4/10.. Loss: 0.9763.. Test accuracy: 0.6252.. 0.0140 s/batch
# Epoch: 4/10.. Loss: 0.9371.. Test accuracy: 0.6486.. 0.0143 s/batch
# Epoch: 4/10.. Loss: 0.9676.. Test accuracy: 0.6385.. 0.0205 s/batch
# Epoch: 4/10.. Loss: 0.9680.. Test accuracy: 0.6266.. 0.0235 s/batch
# Epoch: 4/10.. Loss: 0.9896.. Test accuracy: 0.6285.. 0.0229 s/batch
# Epoch: 4/10.. Loss: 0.9332.. Test accuracy: 0.6363.. 0.0215 s/batch
# Epoch: 4/10.. Loss: 0.9395.. Test accuracy: 0.6389.. 0.0139 s/batch
# Epoch: 4/10.. Loss: 0.9602.. Test accuracy: 0.6246.. 0.0141 s/batch
# Epoch: 4/10.. Loss: 0.9925.. Test accuracy: 0.5979.. 0.0153 s/batch
# Epoch: 4/10.. Loss: 1.0295.. Test accuracy: 0.6070.. 0.0139 s/batch
# Epoch: 4/10.. Loss: 1.0122.. Test accuracy: 0.6406.. 0.0137 s/batch
# Epoch: 4/10.. Loss: 0.9810.. Test accuracy: 0.6305.. 0.0142 s/batch
# Epoch: 4/10.. Loss: 0.9786.. Test accuracy: 0.6221.. 0.0144 s/batch
# Epoch: 4/10.. Loss: 0.9945.. Test accuracy: 0.6443.. 0.0152 s/batch
# Epoch: 4/10.. Loss: 0.9983.. Test accuracy: 0.6281.. 0.0146 s/batch
# Epoch: 4/10.. Loss: 0.9624.. Test accuracy: 0.6404.. 0.0141 s/batch
# Epoch: 4/10.. Loss: 0.9657.. Test accuracy: 0.6426.. 0.0152 s/batch
# Epoch: 4/10.. Loss: 0.9604.. Test accuracy: 0.6307.. 0.0127 s/batch
# Epoch: 4/10.. Loss: 0.9184.. Test accuracy: 0.6484.. 0.0146 s/batch
# Epoch: 4/10.. Loss: 0.9585.. Test accuracy: 0.6447.. 0.0132 s/batch
# Epoch: 4/10.. Loss: 1.0143.. Test accuracy: 0.6260.. 0.0143 s/batch
# Epoch: 4/10.. Loss: 0.9593.. Test accuracy: 0.6270.. 0.0214 s/batch
# Epoch: 4/10.. Loss: 1.0101.. Test accuracy: 0.6525.. 0.0227 s/batch
# Epoch: 4/10.. Loss: 0.9615.. Test accuracy: 0.6164.. 0.0268 s/batch
# Epoch: 4/10.. Loss: 0.9385.. Test accuracy: 0.6408.. 0.0242 s/batch
# Epoch: 4/10.. Loss: 1.0179.. Test accuracy: 0.6123.. 0.0206 s/batch
# Epoch: 5/10.. Loss: 0.9451.. Test accuracy: 0.6400.. 0.0216 s/batch
# Epoch: 5/10.. Loss: 0.9116.. Test accuracy: 0.6260.. 0.0148 s/batch
# Epoch: 5/10.. Loss: 0.8616.. Test accuracy: 0.6133.. 0.0145 s/batch
# Epoch: 5/10.. Loss: 0.9078.. Test accuracy: 0.6256.. 0.0179 s/batch
# Epoch: 5/10.. Loss: 0.9273.. Test accuracy: 0.6156.. 0.0137 s/batch
# Epoch: 5/10.. Loss: 0.9768.. Test accuracy: 0.6484.. 0.0121 s/batch
# Epoch: 5/10.. Loss: 0.8597.. Test accuracy: 0.6459.. 0.0140 s/batch
# Epoch: 5/10.. Loss: 0.9013.. Test accuracy: 0.6490.. 0.0142 s/batch
# Epoch: 5/10.. Loss: 0.9334.. Test accuracy: 0.6480.. 0.0147 s/batch
# Epoch: 5/10.. Loss: 0.9458.. Test accuracy: 0.6639.. 0.0150 s/batch
# Epoch: 5/10.. Loss: 0.9170.. Test accuracy: 0.6254.. 0.0142 s/batch
# Epoch: 5/10.. Loss: 0.8727.. Test accuracy: 0.6328.. 0.0162 s/batch
# Epoch: 5/10.. Loss: 0.9473.. Test accuracy: 0.6482.. 0.0136 s/batch
# Epoch: 5/10.. Loss: 0.9205.. Test accuracy: 0.6426.. 0.0137 s/batch
# Epoch: 5/10.. Loss: 0.9065.. Test accuracy: 0.6486.. 0.0225 s/batch
# Epoch: 5/10.. Loss: 0.9462.. Test accuracy: 0.6549.. 0.0218 s/batch
# Epoch: 5/10.. Loss: 1.0111.. Test accuracy: 0.6359.. 0.0241 s/batch
# Epoch: 5/10.. Loss: 0.9163.. Test accuracy: 0.6336.. 0.0227 s/batch
# Epoch: 5/10.. Loss: 0.9313.. Test accuracy: 0.6359.. 0.0227 s/batch
# Epoch: 5/10.. Loss: 0.9304.. Test accuracy: 0.6545.. 0.0161 s/batch
# Epoch: 5/10.. Loss: 0.9041.. Test accuracy: 0.6408.. 0.0262 s/batch
# Epoch: 5/10.. Loss: 0.8945.. Test accuracy: 0.6432.. 0.0257 s/batch
# Epoch: 5/10.. Loss: 0.9593.. Test accuracy: 0.6486.. 0.0219 s/batch
# Epoch: 5/10.. Loss: 0.9504.. Test accuracy: 0.6541.. 0.0273 s/batch
# Epoch: 5/10.. Loss: 0.9395.. Test accuracy: 0.6346.. 0.0143 s/batch
# Epoch: 5/10.. Loss: 0.8771.. Test accuracy: 0.6297.. 0.0141 s/batch
# Epoch: 5/10.. Loss: 0.9210.. Test accuracy: 0.6305.. 0.0150 s/batch
# Epoch: 5/10.. Loss: 0.8719.. Test accuracy: 0.6305.. 0.0130 s/batch
# Epoch: 5/10.. Loss: 0.9165.. Test accuracy: 0.6426.. 0.0149 s/batch
# Epoch: 5/10.. Loss: 0.9331.. Test accuracy: 0.6504.. 0.0157 s/batch
# Epoch: 5/10.. Loss: 0.9667.. Test accuracy: 0.6354.. 0.0143 s/batch
# Epoch: 5/10.. Loss: 0.9293.. Test accuracy: 0.6439.. 0.0228 s/batch
# Epoch: 5/10.. Loss: 0.9141.. Test accuracy: 0.6555.. 0.0233 s/batch
# Epoch: 5/10.. Loss: 0.9959.. Test accuracy: 0.6309.. 0.0242 s/batch
# Epoch: 5/10.. Loss: 0.9119.. Test accuracy: 0.6471.. 0.0241 s/batch
# Epoch: 5/10.. Loss: 0.9270.. Test accuracy: 0.6334.. 0.0141 s/batch
# Epoch: 5/10.. Loss: 0.9118.. Test accuracy: 0.6479.. 0.0131 s/batch
# Epoch: 5/10.. Loss: 0.9131.. Test accuracy: 0.6477.. 0.0129 s/batch
# Epoch: 6/10.. Loss: 0.8984.. Test accuracy: 0.6605.. 0.0153 s/batch
# Epoch: 6/10.. Loss: 0.8740.. Test accuracy: 0.6309.. 0.0133 s/batch
# Epoch: 6/10.. Loss: 0.9193.. Test accuracy: 0.6363.. 0.0193 s/batch
# Epoch: 6/10.. Loss: 0.8191.. Test accuracy: 0.6568.. 0.0137 s/batch
# Epoch: 6/10.. Loss: 0.8752.. Test accuracy: 0.6473.. 0.0142 s/batch
# Epoch: 6/10.. Loss: 0.8722.. Test accuracy: 0.6545.. 0.0151 s/batch
# Epoch: 6/10.. Loss: 0.8497.. Test accuracy: 0.6352.. 0.0153 s/batch
# Epoch: 6/10.. Loss: 0.8946.. Test accuracy: 0.6404.. 0.0140 s/batch
# Epoch: 6/10.. Loss: 0.8763.. Test accuracy: 0.6529.. 0.0147 s/batch
# Epoch: 6/10.. Loss: 0.8477.. Test accuracy: 0.6586.. 0.0157 s/batch
# Epoch: 6/10.. Loss: 0.8710.. Test accuracy: 0.6561.. 0.0134 s/batch
# Epoch: 6/10.. Loss: 0.9253.. Test accuracy: 0.6529.. 0.0166 s/batch
# Epoch: 6/10.. Loss: 0.9005.. Test accuracy: 0.6338.. 0.0221 s/batch
# Epoch: 6/10.. Loss: 0.9320.. Test accuracy: 0.6256.. 0.0198 s/batch
# Epoch: 6/10.. Loss: 0.8774.. Test accuracy: 0.6574.. 0.0258 s/batch
# Epoch: 6/10.. Loss: 0.8550.. Test accuracy: 0.6432.. 0.0231 s/batch
# Epoch: 6/10.. Loss: 0.8651.. Test accuracy: 0.6449.. 0.0131 s/batch
# Epoch: 6/10.. Loss: 0.8758.. Test accuracy: 0.6482.. 0.0142 s/batch
# Epoch: 6/10.. Loss: 0.8432.. Test accuracy: 0.6348.. 0.0153 s/batch
# Epoch: 6/10.. Loss: 0.9386.. Test accuracy: 0.6307.. 0.0161 s/batch
# Epoch: 6/10.. Loss: 0.9534.. Test accuracy: 0.6311.. 0.0141 s/batch
# Epoch: 6/10.. Loss: 0.9285.. Test accuracy: 0.6521.. 0.0151 s/batch
# Epoch: 6/10.. Loss: 0.8960.. Test accuracy: 0.6307.. 0.0129 s/batch
# Epoch: 6/10.. Loss: 0.8633.. Test accuracy: 0.6494.. 0.0147 s/batch
# Epoch: 6/10.. Loss: 0.8954.. Test accuracy: 0.6520.. 0.0167 s/batch
# Epoch: 6/10.. Loss: 0.8489.. Test accuracy: 0.6434.. 0.0131 s/batch
# Epoch: 6/10.. Loss: 0.8645.. Test accuracy: 0.6482.. 0.0139 s/batch
# Epoch: 6/10.. Loss: 0.9354.. Test accuracy: 0.6479.. 0.0147 s/batch
# Epoch: 6/10.. Loss: 0.9276.. Test accuracy: 0.6494.. 0.0138 s/batch
# Epoch: 6/10.. Loss: 0.9097.. Test accuracy: 0.6525.. 0.0134 s/batch
# Epoch: 6/10.. Loss: 0.9176.. Test accuracy: 0.6516.. 0.0150 s/batch
# Epoch: 6/10.. Loss: 0.8958.. Test accuracy: 0.6381.. 0.0232 s/batch
# Epoch: 6/10.. Loss: 0.8843.. Test accuracy: 0.6602.. 0.0247 s/batch
# Epoch: 6/10.. Loss: 0.8480.. Test accuracy: 0.6564.. 0.0206 s/batch
# Epoch: 6/10.. Loss: 0.9126.. Test accuracy: 0.6332.. 0.0210 s/batch
# Epoch: 6/10.. Loss: 0.8936.. Test accuracy: 0.6393.. 0.0192 s/batch
# Epoch: 6/10.. Loss: 0.9229.. Test accuracy: 0.6582.. 0.0149 s/batch
# Epoch: 6/10.. Loss: 0.9318.. Test accuracy: 0.6615.. 0.0145 s/batch
# Epoch: 7/10.. Loss: 0.8784.. Test accuracy: 0.6471.. 0.0106 s/batch
# Epoch: 7/10.. Loss: 0.8397.. Test accuracy: 0.6482.. 0.0142 s/batch
# Epoch: 7/10.. Loss: 0.8333.. Test accuracy: 0.6773.. 0.0157 s/batch
# Epoch: 7/10.. Loss: 0.8303.. Test accuracy: 0.6682.. 0.0137 s/batch
# Epoch: 7/10.. Loss: 0.8694.. Test accuracy: 0.6492.. 0.0139 s/batch
# Epoch: 7/10.. Loss: 0.8762.. Test accuracy: 0.6605.. 0.0153 s/batch
# Epoch: 7/10.. Loss: 0.8578.. Test accuracy: 0.6580.. 0.0140 s/batch
# Epoch: 7/10.. Loss: 0.8671.. Test accuracy: 0.6609.. 0.0140 s/batch
# Epoch: 7/10.. Loss: 0.8684.. Test accuracy: 0.6715.. 0.0139 s/batch
# Epoch: 7/10.. Loss: 0.8643.. Test accuracy: 0.6520.. 0.0145 s/batch
# Epoch: 7/10.. Loss: 0.8178.. Test accuracy: 0.6520.. 0.0156 s/batch
# Epoch: 7/10.. Loss: 0.8586.. Test accuracy: 0.6674.. 0.0137 s/batch
# Epoch: 7/10.. Loss: 0.8500.. Test accuracy: 0.6699.. 0.0194 s/batch
# Epoch: 7/10.. Loss: 0.8450.. Test accuracy: 0.6578.. 0.0247 s/batch
# Epoch: 7/10.. Loss: 0.9064.. Test accuracy: 0.6479.. 0.0228 s/batch
# Epoch: 7/10.. Loss: 0.9864.. Test accuracy: 0.6498.. 0.0239 s/batch
# Epoch: 7/10.. Loss: 0.8609.. Test accuracy: 0.6609.. 0.0153 s/batch
# Epoch: 7/10.. Loss: 0.8773.. Test accuracy: 0.6781.. 0.0137 s/batch
# Epoch: 7/10.. Loss: 0.8203.. Test accuracy: 0.6420.. 0.0142 s/batch
# Epoch: 7/10.. Loss: 0.8645.. Test accuracy: 0.6443.. 0.0142 s/batch
# Epoch: 7/10.. Loss: 0.8560.. Test accuracy: 0.6654.. 0.0148 s/batch
# Epoch: 7/10.. Loss: 0.8898.. Test accuracy: 0.6471.. 0.0148 s/batch
# Epoch: 7/10.. Loss: 0.8866.. Test accuracy: 0.6535.. 0.0137 s/batch
# Epoch: 7/10.. Loss: 0.8563.. Test accuracy: 0.6645.. 0.0141 s/batch
# Epoch: 7/10.. Loss: 0.8400.. Test accuracy: 0.6668.. 0.0139 s/batch
# Epoch: 7/10.. Loss: 0.8723.. Test accuracy: 0.6469.. 0.0148 s/batch
# Epoch: 7/10.. Loss: 0.8764.. Test accuracy: 0.6500.. 0.0143 s/batch
# Epoch: 7/10.. Loss: 0.9224.. Test accuracy: 0.6521.. 0.0150 s/batch
# Epoch: 7/10.. Loss: 0.8953.. Test accuracy: 0.6605.. 0.0159 s/batch
# Epoch: 7/10.. Loss: 0.9129.. Test accuracy: 0.6605.. 0.0147 s/batch
# Epoch: 7/10.. Loss: 0.8173.. Test accuracy: 0.6576.. 0.0142 s/batch
# Epoch: 7/10.. Loss: 0.8796.. Test accuracy: 0.6482.. 0.0207 s/batch
# Epoch: 7/10.. Loss: 0.8935.. Test accuracy: 0.6305.. 0.0221 s/batch
# Epoch: 7/10.. Loss: 0.9079.. Test accuracy: 0.6521.. 0.0251 s/batch
# Epoch: 7/10.. Loss: 0.8292.. Test accuracy: 0.6555.. 0.0222 s/batch
# Epoch: 7/10.. Loss: 0.8283.. Test accuracy: 0.6428.. 0.0234 s/batch
# Epoch: 7/10.. Loss: 0.8956.. Test accuracy: 0.6629.. 0.0141 s/batch
# Epoch: 7/10.. Loss: 0.8948.. Test accuracy: 0.6699.. 0.0145 s/batch
# Epoch: 7/10.. Loss: 0.8461.. Test accuracy: 0.6543.. 0.0131 s/batch
# Epoch: 8/10.. Loss: 0.8656.. Test accuracy: 0.6580.. 0.0214 s/batch
# Epoch: 8/10.. Loss: 0.7339.. Test accuracy: 0.6434.. 0.0130 s/batch
# Epoch: 8/10.. Loss: 0.8322.. Test accuracy: 0.6480.. 0.0266 s/batch
# Epoch: 8/10.. Loss: 0.7986.. Test accuracy: 0.6555.. 0.0271 s/batch
# Epoch: 8/10.. Loss: 0.8450.. Test accuracy: 0.6457.. 0.0137 s/batch
# Epoch: 8/10.. Loss: 0.8567.. Test accuracy: 0.6457.. 0.0143 s/batch
# Epoch: 8/10.. Loss: 0.8743.. Test accuracy: 0.6752.. 0.0139 s/batch
# Epoch: 8/10.. Loss: 0.8433.. Test accuracy: 0.6730.. 0.0149 s/batch
# Epoch: 8/10.. Loss: 0.8411.. Test accuracy: 0.6668.. 0.0147 s/batch
# Epoch: 8/10.. Loss: 0.8347.. Test accuracy: 0.6785.. 0.0150 s/batch
# Epoch: 8/10.. Loss: 0.8540.. Test accuracy: 0.6646.. 0.0156 s/batch
# Epoch: 8/10.. Loss: 0.8245.. Test accuracy: 0.6621.. 0.0226 s/batch
# Epoch: 8/10.. Loss: 0.8846.. Test accuracy: 0.6471.. 0.0213 s/batch
# Epoch: 8/10.. Loss: 0.8163.. Test accuracy: 0.6732.. 0.0247 s/batch
# Epoch: 8/10.. Loss: 0.8639.. Test accuracy: 0.6451.. 0.0235 s/batch
# Epoch: 8/10.. Loss: 0.8388.. Test accuracy: 0.6553.. 0.0145 s/batch
# Epoch: 8/10.. Loss: 0.8084.. Test accuracy: 0.6654.. 0.0158 s/batch
# Epoch: 8/10.. Loss: 0.8102.. Test accuracy: 0.6721.. 0.0158 s/batch
# Epoch: 8/10.. Loss: 0.8501.. Test accuracy: 0.6568.. 0.0135 s/batch
# Epoch: 8/10.. Loss: 0.8076.. Test accuracy: 0.6373.. 0.0152 s/batch
# Epoch: 8/10.. Loss: 0.8230.. Test accuracy: 0.6748.. 0.0150 s/batch
# Epoch: 8/10.. Loss: 0.8366.. Test accuracy: 0.6561.. 0.0146 s/batch
# Epoch: 8/10.. Loss: 0.8420.. Test accuracy: 0.6766.. 0.0130 s/batch
# Epoch: 8/10.. Loss: 0.8185.. Test accuracy: 0.6588.. 0.0150 s/batch
# Epoch: 8/10.. Loss: 0.8632.. Test accuracy: 0.6473.. 0.0153 s/batch
# Epoch: 8/10.. Loss: 0.9104.. Test accuracy: 0.6746.. 0.0145 s/batch
# Epoch: 8/10.. Loss: 0.8011.. Test accuracy: 0.6785.. 0.0128 s/batch
# Epoch: 8/10.. Loss: 0.8281.. Test accuracy: 0.6754.. 0.0148 s/batch
# Epoch: 8/10.. Loss: 0.8458.. Test accuracy: 0.6551.. 0.0134 s/batch
# Epoch: 8/10.. Loss: 0.8385.. Test accuracy: 0.6436.. 0.0140 s/batch
# Epoch: 8/10.. Loss: 0.8649.. Test accuracy: 0.6701.. 0.0226 s/batch
# Epoch: 8/10.. Loss: 0.8524.. Test accuracy: 0.6402.. 0.0246 s/batch
# Epoch: 8/10.. Loss: 0.8457.. Test accuracy: 0.6451.. 0.0260 s/batch
# Epoch: 8/10.. Loss: 0.8668.. Test accuracy: 0.6490.. 0.0257 s/batch
# Epoch: 8/10.. Loss: 0.8231.. Test accuracy: 0.6645.. 0.0166 s/batch
# Epoch: 8/10.. Loss: 0.8241.. Test accuracy: 0.6473.. 0.0135 s/batch
# Epoch: 8/10.. Loss: 0.8664.. Test accuracy: 0.6482.. 0.0151 s/batch
# Epoch: 8/10.. Loss: 0.8937.. Test accuracy: 0.6654.. 0.0163 s/batch
# Epoch: 9/10.. Loss: 0.7689.. Test accuracy: 0.6783.. 0.0148 s/batch
# Epoch: 9/10.. Loss: 0.7325.. Test accuracy: 0.6668.. 0.0141 s/batch
# Epoch: 9/10.. Loss: 0.8388.. Test accuracy: 0.6533.. 0.0151 s/batch
# Epoch: 9/10.. Loss: 0.7865.. Test accuracy: 0.6469.. 0.0138 s/batch
# Epoch: 9/10.. Loss: 0.8384.. Test accuracy: 0.6549.. 0.0142 s/batch
# Epoch: 9/10.. Loss: 0.8121.. Test accuracy: 0.6658.. 0.0166 s/batch
# Epoch: 9/10.. Loss: 0.8032.. Test accuracy: 0.6562.. 0.0139 s/batch
# Epoch: 9/10.. Loss: 0.8118.. Test accuracy: 0.6580.. 0.0140 s/batch
# Epoch: 9/10.. Loss: 0.7523.. Test accuracy: 0.6539.. 0.0157 s/batch
# Epoch: 9/10.. Loss: 0.7914.. Test accuracy: 0.6629.. 0.0134 s/batch
# Epoch: 9/10.. Loss: 0.7897.. Test accuracy: 0.6650.. 0.0223 s/batch
# Epoch: 9/10.. Loss: 0.8658.. Test accuracy: 0.6561.. 0.0228 s/batch
# Epoch: 9/10.. Loss: 0.8408.. Test accuracy: 0.6482.. 0.0231 s/batch
# Epoch: 9/10.. Loss: 0.8221.. Test accuracy: 0.6631.. 0.0219 s/batch
# Epoch: 9/10.. Loss: 0.8338.. Test accuracy: 0.6578.. 0.0211 s/batch
# Epoch: 9/10.. Loss: 0.7878.. Test accuracy: 0.6699.. 0.0139 s/batch
# Epoch: 9/10.. Loss: 0.8495.. Test accuracy: 0.6605.. 0.0144 s/batch
# Epoch: 9/10.. Loss: 0.8651.. Test accuracy: 0.6727.. 0.0150 s/batch
# Epoch: 9/10.. Loss: 0.7757.. Test accuracy: 0.6641.. 0.0146 s/batch
# Epoch: 9/10.. Loss: 0.8219.. Test accuracy: 0.6687.. 0.0148 s/batch
# Epoch: 9/10.. Loss: 0.8106.. Test accuracy: 0.6838.. 0.0150 s/batch
# Epoch: 9/10.. Loss: 0.8122.. Test accuracy: 0.6686.. 0.0144 s/batch
# Epoch: 9/10.. Loss: 0.8563.. Test accuracy: 0.6664.. 0.0147 s/batch
# Epoch: 9/10.. Loss: 0.8717.. Test accuracy: 0.6672.. 0.0154 s/batch
# Epoch: 9/10.. Loss: 0.7651.. Test accuracy: 0.6568.. 0.0153 s/batch
# Epoch: 9/10.. Loss: 0.8192.. Test accuracy: 0.6539.. 0.0141 s/batch
# Epoch: 9/10.. Loss: 0.7836.. Test accuracy: 0.6691.. 0.0157 s/batch
# Epoch: 9/10.. Loss: 0.8395.. Test accuracy: 0.6637.. 0.0140 s/batch
# Epoch: 9/10.. Loss: 0.7858.. Test accuracy: 0.6768.. 0.0147 s/batch
# Epoch: 9/10.. Loss: 0.8577.. Test accuracy: 0.6627.. 0.0185 s/batch
# Epoch: 9/10.. Loss: 0.8254.. Test accuracy: 0.6705.. 0.0204 s/batch
# Epoch: 9/10.. Loss: 0.8416.. Test accuracy: 0.6703.. 0.0235 s/batch
# Epoch: 9/10.. Loss: 0.8482.. Test accuracy: 0.6699.. 0.0221 s/batch
# Epoch: 9/10.. Loss: 0.8557.. Test accuracy: 0.6656.. 0.0197 s/batch
# Epoch: 9/10.. Loss: 0.8523.. Test accuracy: 0.6701.. 0.0148 s/batch
# Epoch: 9/10.. Loss: 0.8043.. Test accuracy: 0.6521.. 0.0140 s/batch
# Epoch: 9/10.. Loss: 0.8289.. Test accuracy: 0.6496.. 0.0134 s/batch
# Epoch: 9/10.. Loss: 0.8395.. Test accuracy: 0.6375.. 0.0145 s/batch
# Epoch: 10/10.. Loss: 0.8175.. Test accuracy: 0.6479.. 0.0129 s/batch
# Epoch: 10/10.. Loss: 0.7469.. Test accuracy: 0.6660.. 0.0129 s/batch
# Epoch: 10/10.. Loss: 0.7227.. Test accuracy: 0.6742.. 0.0144 s/batch
# Epoch: 10/10.. Loss: 0.7488.. Test accuracy: 0.6654.. 0.0156 s/batch
# Epoch: 10/10.. Loss: 0.7768.. Test accuracy: 0.6639.. 0.0137 s/batch
# Epoch: 10/10.. Loss: 0.8163.. Test accuracy: 0.6568.. 0.0143 s/batch
# Epoch: 10/10.. Loss: 0.8190.. Test accuracy: 0.6707.. 0.0181 s/batch
# Epoch: 10/10.. Loss: 0.7714.. Test accuracy: 0.6494.. 0.0142 s/batch
# Epoch: 10/10.. Loss: 0.7700.. Test accuracy: 0.6658.. 0.0141 s/batch
# Epoch: 10/10.. Loss: 0.7644.. Test accuracy: 0.6639.. 0.0160 s/batch
# Epoch: 10/10.. Loss: 0.8102.. Test accuracy: 0.6832.. 0.0152 s/batch
# Epoch: 10/10.. Loss: 0.8202.. Test accuracy: 0.6658.. 0.0225 s/batch
# Epoch: 10/10.. Loss: 0.8245.. Test accuracy: 0.6520.. 0.0217 s/batch
# Epoch: 10/10.. Loss: 0.8178.. Test accuracy: 0.6619.. 0.0248 s/batch
# Epoch: 10/10.. Loss: 0.8048.. Test accuracy: 0.6707.. 0.0230 s/batch
# Epoch: 10/10.. Loss: 0.7767.. Test accuracy: 0.6674.. 0.0147 s/batch
# Epoch: 10/10.. Loss: 0.7566.. Test accuracy: 0.6732.. 0.0150 s/batch
# Epoch: 10/10.. Loss: 0.8104.. Test accuracy: 0.6723.. 0.0135 s/batch
# Epoch: 10/10.. Loss: 0.7940.. Test accuracy: 0.6465.. 0.0136 s/batch
# Epoch: 10/10.. Loss: 0.7424.. Test accuracy: 0.6723.. 0.0155 s/batch
# Epoch: 10/10.. Loss: 0.8149.. Test accuracy: 0.6691.. 0.0151 s/batch
# Epoch: 10/10.. Loss: 0.7786.. Test accuracy: 0.6600.. 0.0150 s/batch
# Epoch: 10/10.. Loss: 0.8211.. Test accuracy: 0.6691.. 0.0159 s/batch
# Epoch: 10/10.. Loss: 0.7587.. Test accuracy: 0.6641.. 0.0144 s/batch
# Epoch: 10/10.. Loss: 0.8774.. Test accuracy: 0.6617.. 0.0155 s/batch
# Epoch: 10/10.. Loss: 0.8563.. Test accuracy: 0.6514.. 0.0137 s/batch
# Epoch: 10/10.. Loss: 0.8313.. Test accuracy: 0.6805.. 0.0136 s/batch
# Epoch: 10/10.. Loss: 0.8229.. Test accuracy: 0.6717.. 0.0160 s/batch
# Epoch: 10/10.. Loss: 0.8217.. Test accuracy: 0.6738.. 0.0134 s/batch
# Epoch: 10/10.. Loss: 0.7875.. Test accuracy: 0.6691.. 0.0134 s/batch
# Epoch: 10/10.. Loss: 0.7931.. Test accuracy: 0.6770.. 0.0227 s/batch
# Epoch: 10/10.. Loss: 0.8507.. Test accuracy: 0.6586.. 0.0206 s/batch
# Epoch: 10/10.. Loss: 0.7936.. Test accuracy: 0.6600.. 0.0241 s/batch
# Epoch: 10/10.. Loss: 0.7945.. Test accuracy: 0.6496.. 0.0214 s/batch
# Epoch: 10/10.. Loss: 0.8042.. Test accuracy: 0.6645.. 0.0157 s/batch
# Epoch: 10/10.. Loss: 0.8542.. Test accuracy: 0.6617.. 0.0146 s/batch
# Epoch: 10/10.. Loss: 0.8009.. Test accuracy: 0.6748.. 0.0149 s/batch
# Epoch: 10/10.. Loss: 0.8613.. Test accuracy: 0.6658.. 0.0154 s/batch
# Epoch: 10/10.. Loss: 0.7977.. Test accuracy: 0.6725.. 0.0110 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)
torch.save(net.state_dict(), '/content/drive/MyDrive/models/graded/hw1/cnn.pt')

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet() # Untrained model

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
# "features[0]" is your first convolutionnal layer, you might have to change it to conv1 if it was the name you gave it to
filters_untrained = model.features[0].weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
# Same thing here
filters_trained = net.features[0].weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.
#
# ANSWER: The first-layer filters are no longer random color patches. They are now more structured and smoother. Some seem to detect patterns like color contrasts, bolbs and maybe some edge transitions

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[0].unsqueeze(0).to(device)

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.features[0], sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# Play with the index of the chosen sample to notice more patterns and answer the question

# %% [markdown]
# ### 1. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?
#
# ANSWER: These maps mostly pick up simple things like edges, lines, and rough contours. A few clearly highlight parts of the airplane shape, like the wings or body, while others respond to contrast or small texture details in the image.
#
# ---
#
# ### 2. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?
#
# ANSWER: After training, the activations usually look more focused and meaningful because the filters have learned useful patterns. In an untrained network, they would look more random. So training helps the model go from random responses to detecting features that actually matter for recognizing the object.
